# %%
# importing the necessary library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# loading the data
df=pd.read_csv("homelessness.csv")

# %%
# heading of the data
df.head()
# Out:
#    Unnamed: 0              region       state  individuals  family_members  \
# 0           0  East South Central     Alabama       2570.0           864.0
# 1           1             Pacific      Alaska       1434.0           582.0
# 2           2            Mountain     Arizona       7259.0          2606.0
# 3           3  West South Central    Arkansas       2280.0           432.0
# 4           4             Pacific  California     109008.0         20964.0
#
#    state_pop
# 0    4887681
# 1     735139
# 2    7158024
# 3    3009733
# 4   39461588

# %%
# Distplaying the columns names

df.columns
# Out:
# Index(['Unnamed: 0', 'region', 'state', 'individuals', 'family_members',
#        'state_pop'],
#       dtype='object')

# %%
# distplaying the values of the dataframe as numpay

df.values
# Out:
# array([[0, 'East South Central', 'Alabama', 2570.0, 864.0, 4887681],
#        [1, 'Pacific', 'Alaska', 1434.0, 582.0, 735139],
#        [2, 'Mountain', 'Arizona', 7259.0, 2606.0, 7158024],
#        [3, 'West South Central', 'Arkansas', 2280.0, 432.0, 3009733],
#        [4, 'Pacific', 'California', 109008.0, 20964.0, 39461588],
#        [5, 'Mountain', 'Colorado', 7607.0, 3250.0, 5691287],
#        [6, 'New England', 'Connecticut', 2280.0, 1696.0, 3571520],
#        [7, 'South Atlantic', 'Delaware', 708.0, 374.0, 965479],
#        [8, 'South Atlantic', 'District of Columbia', 3770.0, 3134.0,
#         701547],
#        [9, 'South Atlantic', 'Florida', 21443.0, 9587.0, 21244317],
#        [10, 'South Atlantic', 'Georgia', 6943.0, 2556.0, 10511131],
#        [11, 'Pacific', 'Hawaii', 4131.0, 2399.0, 1420593],
#        [12, 'Mountain', 'Idaho', 1297.0, 715.0, 1750536],
#        [13, 'East North Central', 'Illinois', 6752.0, 3891.0, 12723071],
# ...

# %%
# Displaying the index we have in our dataset or number of row

df.index
# Out:
# RangeIndex(start=0, stop=51, step=1)

# %% [markdown]
# # Sorting and Subsetting

# %%
# .sort_values(column_name, argument or order)

df.sort_values("state", ascending=[True]) # one column
df.sort_values(['state','region'], ascending=[False,True])# for multiple columns
# Out:
#     Unnamed: 0              region                 state  individuals  \
# 50          50            Mountain               Wyoming        434.0
# 49          49  East North Central             Wisconsin       2740.0
# 48          48      South Atlantic         West Virginia       1021.0
# 47          47             Pacific            Washington      16424.0
# 46          46      South Atlantic              Virginia       3928.0
# 45          45         New England               Vermont        780.0
# 44          44            Mountain                  Utah       1904.0
# 43          43  West South Central                 Texas      19199.0
# 42          42  East South Central             Tennessee       6139.0
# 41          41  West North Central          South Dakota        836.0
# 40          40      South Atlantic        South Carolina       3082.0
# 39          39         New England          Rhode Island        747.0
# ...

# %% [markdown]
# # Subsetting rows

# %%
# checking the values of one column only

df['state'] # for one column
df[["state","region"]] # selecting multiple columns
# Out:
#                    state              region
# 0                Alabama  East South Central
# 1                 Alaska             Pacific
# 2                Arizona            Mountain
# 3               Arkansas  West South Central
# 4             California             Pacific
# 5               Colorado            Mountain
# 6            Connecticut         New England
# 7               Delaware      South Atlantic
# 8   District of Columbia      South Atlantic
# 9                Florida      South Atlantic
# 10               Georgia      South Atlantic
# 11                Hawaii             Pacific
# 12                 Idaho            Mountain
# 13              Illinois  East North Central
# 14               Indiana  East North Central
# 15                  Iowa  West North Central
# 16                Kansas  West North Central
# 17              Kentucky  East South Central
# 18             Louisiana  West South Central
# 19                 Maine         New England
# ...

# %%
# using boolean
# find the all state whose region is not the West North Central

df[df['region']=='West North Central']
# Out:
#     Unnamed: 0              region         state  individuals  family_members  \
# 15          15  West North Central          Iowa       1711.0          1038.0
# 16          16  West North Central        Kansas       1443.0           773.0
# 23          23  West North Central     Minnesota       3993.0          3250.0
# 25          25  West North Central      Missouri       3776.0          2107.0
# 27          27  West North Central      Nebraska       1745.0           676.0
# 34          34  West North Central  North Dakota        467.0            75.0
# 41          41  West North Central  South Dakota        836.0           323.0
#
#     state_pop
# 15    3148618
# 16    2911359
# 23    5606249
# 25    6121623
# 27    1925614
# 34     758080
# 41     878698

# %%
# The Mojave Desert states
canu = ["California", "Arizona", "Nevada", "Utah"]

# Filter for rows in the Mojave Desert states using .isin() function
Mojave_Desert= df[df['state'].isin(canu)]
print(Mojave_Desert)
# Out:
#     Unnamed: 0    region       state  individuals  family_members  state_pop
# 2            2  Mountain     Arizona       7259.0          2606.0    7158024
# 4            4   Pacific  California     109008.0         20964.0   39461588
# 28          28  Mountain      Nevada       7058.0           486.0    3027341
# 44          44  Mountain        Utah       1904.0           972.0    3153550

# %% [markdown]
# Add a new column to homelessness, named total, containing the sum of the individuals and family_members columns.
# Add another column to homelessness, named p_individuals, containing the proportion of homeless people in each state who are individuals.

# %%
# adding the total column on dataset as the addition of indiviuals and family member 
df['total']=df['individuals']+df['family_members']
# adding the p_individuals column on dataset ad the individuals over total 

df['p_individuals']=df['individuals']/df['total']
df
# Out:
#     Unnamed: 0              region                 state  individuals  \
# 0            0  East South Central               Alabama       2570.0
# 1            1             Pacific                Alaska       1434.0
# 2            2            Mountain               Arizona       7259.0
# 3            3  West South Central              Arkansas       2280.0
# 4            4             Pacific            California     109008.0
# 5            5            Mountain              Colorado       7607.0
# 6            6         New England           Connecticut       2280.0
# 7            7      South Atlantic              Delaware        708.0
# 8            8      South Atlantic  District of Columbia       3770.0
# 9            9      South Atlantic               Florida      21443.0
# 10          10      South Atlantic               Georgia       6943.0
# 11          11             Pacific                Hawaii       4131.0
# ...

# %% [markdown]
# Add a column to homelessness, indiv_per_10k, containing the number of homeless individuals per ten thousand people in each state.
# Subset rows where indiv_per_10k is higher than 20, assigning to high_homelessness.
# Sort high_homelessness by descending indiv_per_10k, assigning to high_homelessness_srt.
# Select only the state and indiv_per_10k columns of high_homelessness_srt and save as result. Look at the result.

# %%
# finding the population per 10k 
df['indiv_per_10k']=10000*df['individuals']/df['state_pop']

# finding the high homelessness greater than 20
high_homelessness=df[df['indiv_per_10k']>20]

# high homeless sorted in assending order 
high_homelessness_srt= high_homelessness.sort_values('indiv_per_10k',ascending=False)

# displaying the indiv_per_10k and state columns only 
result=high_homelessness_srt[['indiv_per_10k','state']]
result
# Out:
#     indiv_per_10k                 state
# 8       53.738381  District of Columbia
# 11      29.079406                Hawaii
# 4       27.623825            California
# 37      26.636307                Oregon
# 28      23.314189                Nevada
# 47      21.829195            Washington
# 32      20.392363              New York

# %% [markdown]
# # # summary statistics in pandas

# %% [markdown]
# #  .agg() function

# %%
# using the .agg() method which help to perfor a custom statistica on our dataset 
# this is the function that calculate the percentile of thirtieth 
def pct30(column):
    return column.quantile(0.3)
def pct40(column):
    return column.quantile(0.4)
    
# now we can call the column and apply the function on it using agg function 

dogs['height_cm'].agg(pct30)

# we can also using the agg for multiple columns 

dogs[['heigh_cm','weight_cm']].agg(pct30)

# we can pass alist of functions into agg() function 

dogs['height_cm'].agg([pct30,pct40])
# Out:
# 1745.0

# %% [markdown]
# # cumulative sum [.cumsum()]

# %%
# cumulative sum is for calculating the sum of all items one plus the previous 

dogs['weigt_cm'].cumsum()

# %%
sales=pd.read_csv('sales_subset.csv')

#printing head()
print(sales.head())
# getting some info on my data 

print(sales.info())
# calculating the mean of weekly_sales column
print("mean:",sales['weekly_sales'].mean())
# getting the median of the weekly_sales column 

print('median',sales['weekly_sales'].median())
# Out:
#    Unnamed: 0  store type  department        date  weekly_sales  is_holiday  \
# 0           0      1    A           1  2010-02-05      24924.50       False
# 1           1      1    A           1  2010-03-05      21827.90       False
# 2           2      1    A           1  2010-04-02      57258.43       False
# 3           3      1    A           1  2010-05-07      17413.94       False
# 4           4      1    A           1  2010-06-04      17558.09       False
#
#    temperature_c  fuel_price_usd_per_l  unemployment
# 0       5.727778              0.679451         8.106
# 1       8.055556              0.693452         8.106
# 2      16.816667              0.718284         7.808
# 3      22.527778              0.748928         7.808
# 4      27.050000              0.714586         7.808
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10774 entries, 0 to 10773
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ...

# %%
# A custom IQR function
def iqr(column):
    return column.quantile(0.75) - column.quantile(0.25)
    
# Print IQR of the temperature_c column
print(sales['temperature_c'].agg(iqr))
# Out:
# 16.583333333333336

# %%
Sort the rows of sales_1_1 by the date column in ascending order.
Get the cumulative sum of weekly_sales and add it as a new column of sales_1_1 called cum_weekly_sales.
Get the cumulative maximum of weekly_sales, and add it as a column called cum_max_sales.
Print the date, weekly_sales, cum_weekly_sales, and cum_max_sales columns.

# %%
sales_1_1=pd.DataFrame(sales['date'])

# sorting by date 

sales_1_1=sales_1_1.sort_values('date',ascending=True)
# getting the cumulative sum of the weekly_sales
sales_1_1['cum_weekly_sales']=sales['weekly_sales'].cumsum()
# getting the cumulatinve maximum

sales_1_1['cum_max_sales']=sales['weekly_sales'].cummax()
sales_1_1
# getting the cumulative minimun 

sales_1_1['cum_min_sales']=sales['weekly_sales'].cummin()
sales_1_1
# Out:
#              date  cum_weekly_sales  cum_max_sales  cum_min_sales
# 0      2010-02-05      2.492450e+04       24924.50        24924.5
# 6437   2010-02-05      1.629610e+08      293966.05        -1098.0
# 1249   2010-02-05      2.668539e+07      140504.41         -698.0
# 6449   2010-02-05      1.633879e+08      293966.05        -1098.0
# 6461   2010-02-05      1.635954e+08      293966.05        -1098.0
# ...           ...               ...            ...            ...
# 3592   2012-10-05      8.543040e+07      178982.89        -1098.0
# 8108   2012-10-05      2.028157e+08      293966.05        -1098.0
# 10773  2012-10-05      2.568947e+08      293966.05        -1098.0
# 6257   2012-10-12      1.583335e+08      293966.05        -1098.0
# 3384   2012-10-26      7.879133e+07      178982.89        -1098.0
#
# [10774 rows x 4 columns]

# %% [markdown]
# # Counting values

# %% [markdown]
# Remove rows of sales with duplicate pairs of store and type and save as store_types and print the head.
# Remove rows of sales with duplicate pairs of store and department and save as store_depts and print the head.
# Subset the rows that are holiday weeks using the is_holiday column, and drop the duplicate dates, saving as holiday_dates.
# Select the date column of holiday_dates, and print.

# %%
store_types=sales.drop_duplicates(subset=['store','type'])
store_types.head()
type(store_types)
# Out:
# pandas.core.frame.DataFrame

# %%
store_depts=sales.drop_duplicates(subset=['store','department'])
store_depts.head()
# Out:
#     Unnamed: 0  store type  department        date  weekly_sales  is_holiday  \
# 0            0      1    A           1  2010-02-05      24924.50       False
# 12          12      1    A           2  2010-02-05      50605.27       False
# 24          24      1    A           3  2010-02-05      13740.12       False
# 36          36      1    A           4  2010-02-05      39954.04       False
# 48          48      1    A           5  2010-02-05      32229.38       False
#
#     temperature_c  fuel_price_usd_per_l  unemployment
# 0        5.727778              0.679451         8.106
# 12       5.727778              0.679451         8.106
# 24       5.727778              0.679451         8.106
# 36       5.727778              0.679451         8.106
# 48       5.727778              0.679451         8.106

# %%
holiday_dates=sales[sales['is_holiday']].drop_duplicates(subset=['date'])
holiday_dates.head()
# Out:
#       Unnamed: 0  store type  department        date  weekly_sales  \
# 498          498      1    A          45  2010-09-10         11.47
# 691          691      1    A          77  2011-11-25       1431.00
# 2315        2315      4    A          47  2010-02-12        498.00
# 6735        6735     19    A          39  2012-09-07         13.41
# 6810        6810     19    A          47  2010-12-31       -449.00
#
#       is_holiday  temperature_c  fuel_price_usd_per_l  unemployment
# 498         True      25.938889              0.677602         7.787
# 691         True      15.633333              0.854861         7.866
# 2315        True      -1.755556              0.679715         8.623
# 6735        True      22.333333              1.076766         8.193
# 6810        True      -1.861111              0.881278         8.067

# %%
holiday_dates['date']
# Out:
# 498     2010-09-10
# 691     2011-11-25
# 2315    2010-02-12
# 6735    2012-09-07
# 6810    2010-12-31
# 6815    2012-02-10
# 6820    2011-09-09
# Name: date, dtype: object

# %% [markdown]
# Count the number of stores of each store type in store_types.
# Count the proportion of stores of each store type in store_types.
# Count the number of different departments in store_depts, sorting the counts in descending order.
# Count the proportion of different departments in store_depts, sorting the proportions in descending order.

# %%
# Count the number of stores of each type
store_types=store_types['type'].value_counts()
store_types
# Out:
# A    11
# B     1
# Name: type, dtype: int64

# %%
#Get the proportion of stores of each type/ summary statistics 
store_prepo= store_types['type'].value_counts(normalize=True)
store_prepo

# %%
# Count the number of each department number and sort
dept_count_sorted=store_depts['department'].value_counts(sort=True)
dept_count_sorted

# %%
# Get the proportion of departments of each number and sort
dept_prep=store_depts['department'].value_counts(sort=True,normalize=True)
dept_prep

# %% [markdown]
# # Grouped statistic summary(groupby())

# %% [markdown]
# Calculate the total weekly_sales over the whole dataset.
# Subset for type "A" stores, and calculate their total weekly sales.
# Do the same for type "B" and type "C" stores.
# Combine the A/B/C results into a list, and divide by sales_all to get the proportion of sales by type.

# %%
# Calc total weekly sales
sales_all=sales['weekly_sales'].sum()
# Out:
# 256894718.89999998

# %%
# Subset for type A stores, calc total weekly sales
sales_A=sales[sales['type']=='A']['weekly_sales'].sum()
sales_A
# Out:
# 233716315.01

# %%
#  Subset for type B stores, calc total weekly sales
sales_B=sales[sales['type']=='B']['weekly_sales'].sum()
sales_B
# Out:
# 23178403.89

# %%
#  Subset for type C stores, calc total weekly sales
sales_C=sales[sales['type']=='C']['weekly_sales'].sum()
sales_C
# Out:
# 0.0

# %%
# Get proportion for each type
all_sales= [sales_A,sales_B,sales_C]/sales_all
all_sales
# Out:
# array([0.9097747, 0.0902253, 0.       ])

# %% [markdown]
# # groupby()

# %% [markdown]
# Group sales by "type", take the sum of "weekly_sales", and store as sales_by_type.
# Calculate the proportion of sales at each store type by dividing by the sum of sales_by_type. Assign to sales_propn_by_type.

# %%
sales_by_type=sales.groupby('type')['weekly_sales'].sum()
sales_by_type
# Out:
# type
# A    2.337163e+08
# B    2.317840e+07
# Name: weekly_sales, dtype: float64

# %%
sales_propn_by_type=sales_by_type/sum(sales_by_type)
sales_propn_by_type
# Out:
# type
# A    0.909775
# B    0.090225
# Name: weekly_sales, dtype: float64

# %% [markdown]
# Group sales by "type" and "is_holiday", take the sum of weekly_sales, and store as sales_by_type_is_holiday.

# %%
sales_by_type_is_holiday=sales.groupby(['type','is_holiday']).sum()
sales_by_type_is_holiday
# Out:
# C:\Users\WIN PRO 11\AppData\Local\Temp\ipykernel_8044\3740135960.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sales_by_type_is_holiday=sales.groupby(['type','is_holiday']).sum()
#                  Unnamed: 0   store  department  weekly_sales  temperature_c  \
# type is_holiday
# A    False         54150747  156684      444331  2.336927e+08  149917.083333
#      True            236167     667        2572  2.360181e+04     446.633333
# B    False          3638850    9000       40155  2.317678e+07   19087.772222
#      True              8387      20         122  1.621410e+03      44.844444
#
#                  fuel_price_usd_per_l  unemployment
# type is_holiday
# A    False                7318.270676     78392.208
#      True                   32.606772       313.404
# ...

# %% [markdown]
# Import numpy with the alias np.
# Get the min, max, mean, and median of weekly_sales for each store type using .groupby() and .agg(). Store this as sales_stats. Make sure to use numpy functions!
# Get the min, max, mean, and median of unemployment and fuel_price_usd_per_l for each store type. Store this as unemp_fuel_stats.

# %%
import numpy as np

sales_stats= sales.groupby('type')['weekly_sales'].agg([np.mean,np.min,np.max,np.median])
sales_stats
# Out:
#               mean    amin       amax    median
# type
# A     23674.667242 -1098.0  293966.05  11943.92
# B     25696.678370  -798.0  232558.51  13336.08

# %%
unemp_fuel_stats=sales.groupby('type')['fuel_price_usd_per_l','unemployment'].agg([np.min,np.max,np.mean,np.median])
unemp_fuel_stats
# Out:
# C:\Users\WIN PRO 11\AppData\Local\Temp\ipykernel_8044\3872863734.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   unemp_fuel_stats=sales.groupby('type')['fuel_price_usd_per_l','unemployment'].agg([np.min,np.max,np.mean,np.median])
#      fuel_price_usd_per_l                               unemployment         \
#                      amin      amax      mean    median         amin   amax
# type
# A                0.664129  1.107410  0.744619  0.735455        3.879  8.992
# B                0.760023  1.107674  0.805858  0.803348        7.170  9.765
#
#
#           mean median
# type
# A     7.972611  8.067
# B     9.279323  9.199

# %% [markdown]
# # Pivot Tables

# %% [markdown]
# Get the mean weekly_sales by type using .pivot_table() and store as mean_sales_by_type.

# %%
mean_sales_by_type=sales.pivot_table(values='weekly_sales',index='type')
mean_sales_by_type
# Out:
#       weekly_sales
# type
# A     23674.667242
# B     25696.678370

# %% [markdown]
# Get the mean and median (using NumPy functions) of weekly_sales by type using .pivot_table() and store as mean_med_sales_by_type.

# %%
mean_med_sales_by_type=sales.pivot_table(values='weekly_sales',index='type',aggfunc=[np.mean,np.median])
mean_med_sales_by_type
# Out:
#               mean       median
#       weekly_sales weekly_sales
# type
# A     23674.667242     11943.92
# B     25696.678370     13336.08

# %% [markdown]
# Get the mean of weekly_sales by type and is_holiday using .pivot_table() and store as mean_sales_by_type_holiday.

# %%
mean_sales_by_type_holiday=sales.pivot_table(values='weekly_sales',columns='is_holiday',index='type')
mean_sales_by_type_holiday
# Out:
# is_holiday         False      True
# type
# A           23768.583523  590.04525
# B           25751.980533  810.70500

# %% [markdown]
# Print the mean weekly_sales by department and type, filling in any missing values with 0.

# %%
print(sales.pivot_table(values='weekly_sales', index='department',columns='type',fill_value=0, margins=True),
     )
# Out:
# type                   A              B           All
# department
# 1           30961.725379   44050.626667  32052.467153
# 2           67600.158788  112958.526667  71380.022778
# 3           17160.002955   30580.655000  18278.390625
# 4           44285.399091   51219.654167  44863.253681
# 5           34821.011364   63236.875000  37189.000000
# ...                  ...            ...           ...
# 96          21367.042857    9528.538333  20337.607681
# 97          28471.266970    5828.873333  26584.400833
# 98          12875.423182     217.428333  11820.590278
# 99            379.123659       0.000000    379.123659
# All         23674.667242   25696.678370  23843.950149
#
# [81 rows x 3 columns]

# %% [markdown]
# # Explicit indexes

# %%
temperatures=pd.read_csv("temperatures.csv")
temperatures.head()
# Out:
#    Unnamed: 0        date     city        country  avg_temp_c
# 0           0  2000-01-01  Abidjan  Côte D'Ivoire      27.293
# 1           1  2000-02-01  Abidjan  Côte D'Ivoire      27.685
# 2           2  2000-03-01  Abidjan  Côte D'Ivoire      29.061
# 3           3  2000-04-01  Abidjan  Côte D'Ivoire      28.162
# 4           4  2000-05-01  Abidjan  Côte D'Ivoire      27.547

# %% [markdown]
# 1.Look at temperatures.
# 2.Set the index of temperatures to "city", assigning to temperatures_ind.
# 3.Look at temperatures_ind. How is it different from temperatures?
# 4.Reset the index of temperatures_ind, keeping its contents.
# 5.Reset the index of temperatures_ind, dropping its contents.

# %%
# 1.Look at temperatures.
temperatures.head()
# Out:
#    Unnamed: 0        date     city        country  avg_temp_c
# 0           0  2000-01-01  Abidjan  Côte D'Ivoire      27.293
# 1           1  2000-02-01  Abidjan  Côte D'Ivoire      27.685
# 2           2  2000-03-01  Abidjan  Côte D'Ivoire      29.061
# 3           3  2000-04-01  Abidjan  Côte D'Ivoire      28.162
# 4           4  2000-05-01  Abidjan  Côte D'Ivoire      27.547

# %%
# 2. 2.Set the index of temperatures to "city", assigning to temperatures_ind.

temperatures_ind=temperatures.set_index('city')
temperatures_ind.head()
# Out:
#          Unnamed: 0        date        country  avg_temp_c
# city
# Abidjan           0  2000-01-01  Côte D'Ivoire      27.293
# Abidjan           1  2000-02-01  Côte D'Ivoire      27.685
# Abidjan           2  2000-03-01  Côte D'Ivoire      29.061
# Abidjan           3  2000-04-01  Côte D'Ivoire      28.162
# Abidjan           4  2000-05-01  Côte D'Ivoire      27.547

# %%
#3.Look at temperatures_ind. How is it different from temperatures?

#4.Reset the index of temperatures_ind, keeping its contents.

temperatures_ind=temperatures_ind.reset_index()
temperatures_ind.head()
# Out:
#       city  Unnamed: 0        date        country  avg_temp_c
# 0  Abidjan           0  2000-01-01  Côte D'Ivoire      27.293
# 1  Abidjan           1  2000-02-01  Côte D'Ivoire      27.685
# 2  Abidjan           2  2000-03-01  Côte D'Ivoire      29.061
# 3  Abidjan           3  2000-04-01  Côte D'Ivoire      28.162
# 4  Abidjan           4  2000-05-01  Côte D'Ivoire      27.547

# %%
#5.Reset the index of temperatures_ind, dropping its contents.

print(temperatures_ind.reset_index(drop=True))
# Out:
#           city  Unnamed: 0        date        country  avg_temp_c
# 0      Abidjan           0  2000-01-01  Côte D'Ivoire      27.293
# 1      Abidjan           1  2000-02-01  Côte D'Ivoire      27.685
# 2      Abidjan           2  2000-03-01  Côte D'Ivoire      29.061
# 3      Abidjan           3  2000-04-01  Côte D'Ivoire      28.162
# 4      Abidjan           4  2000-05-01  Côte D'Ivoire      27.547
# ...        ...         ...         ...            ...         ...
# 16495     Xian       16495  2013-05-01          China      18.979
# 16496     Xian       16496  2013-06-01          China      23.522
# 16497     Xian       16497  2013-07-01          China      25.251
# 16498     Xian       16498  2013-08-01          China      24.528
# 16499     Xian       16499  2013-09-01          China         NaN
#
# [16500 rows x 5 columns]

# %% [markdown]
# # Subsetting with .loc[]

# %% [raw]
# 1.Create a list called cities that contains "Moscow" and "Saint Petersburg".
# 2.Use [] subsetting to filter temperatures for rows where the city column takes a value in the cities list.
# 3.Use .loc[] subsetting to filter temperatures_ind for rows where the city is in the cities list.

# %%
# 1.Create a list called cities that contains "Moscow" and "Saint Petersburg".

cities=['Moscow','Saint Petersburg']
print(temperatures[temperatures['city'].isin(cities)])
# Out:
#        Unnamed: 0        date              city country  avg_temp_c
# 10725       10725  2000-01-01            Moscow  Russia      -7.313
# 10726       10726  2000-02-01            Moscow  Russia      -3.551
# 10727       10727  2000-03-01            Moscow  Russia      -1.661
# 10728       10728  2000-04-01            Moscow  Russia      10.096
# 10729       10729  2000-05-01            Moscow  Russia      10.357
# ...           ...         ...               ...     ...         ...
# 13360       13360  2013-05-01  Saint Petersburg  Russia      12.355
# 13361       13361  2013-06-01  Saint Petersburg  Russia      17.185
# 13362       13362  2013-07-01  Saint Petersburg  Russia      17.234
# 13363       13363  2013-08-01  Saint Petersburg  Russia      17.153
# 13364       13364  2013-09-01  Saint Petersburg  Russia         NaN
#
# [330 rows x 5 columns]

# %% [raw]
# Set the index of temperatures to the "country" and "city" columns, and assign this to temperatures_ind.
# Specify two country/city pairs to keep: "Brazil"/"Rio De Janeiro" and "Pakistan"/"Lahore", assigning to rows_to_keep.
# Print and subset temperatures_ind for rows_to_keep using .loc[].

# %%
# setting country and city as the index of this dataset 

temperatures_ind=temperatures.set_index(['country','city'])
temperatures_ind.head()
# Out:
#                        Unnamed: 0        date  avg_temp_c
# country       city
# Côte D'Ivoire Abidjan           0  2000-01-01      27.293
#               Abidjan           1  2000-02-01      27.685
#               Abidjan           2  2000-03-01      29.061
#               Abidjan           3  2000-04-01      28.162
#               Abidjan           4  2000-05-01      27.547

# %%
# using iloc[] on tuples 
rows_to_keep=[('Brazil','Rio De Janeiro'),('Pakistan','Lahore')]

# %%
# printing a subse on temperature_ind using lo[]

temperatures_ind.loc[rows_to_keep]
# Out:
#                          Unnamed: 0        date  avg_temp_c
# country  city
# Brazil   Rio De Janeiro       12540  2000-01-01      25.974
#          Rio De Janeiro       12541  2000-02-01      26.699
#          Rio De Janeiro       12542  2000-03-01      26.270
#          Rio De Janeiro       12543  2000-04-01      25.750
#          Rio De Janeiro       12544  2000-05-01      24.356
# ...                             ...         ...         ...
# Pakistan Lahore                8575  2013-05-01      33.457
#          Lahore                8576  2013-06-01      34.456
#          Lahore                8577  2013-07-01      33.279
#          Lahore                8578  2013-08-01      31.511
#          Lahore                8579  2013-09-01         NaN
#
# [330 rows x 3 columns]

# %% [raw]
# Sort temperatures_ind by the index values.
# Sort temperatures_ind by the index values at the "city" level.
# Sort temperatures_ind by ascending country then descending city.

# %%
#sorting by index 

print(temperatures_ind.sort_index())
# Out:
#                     Unnamed: 0        date  avg_temp_c
# country     city
# Afghanistan Kabul         7260  2000-01-01       3.326
#             Kabul         7261  2000-02-01       3.454
#             Kabul         7262  2000-03-01       9.612
#             Kabul         7263  2000-04-01      17.925
#             Kabul         7264  2000-05-01      24.658
# ...                        ...         ...         ...
# Zimbabwe    Harare        5605  2013-05-01      18.298
#             Harare        5606  2013-06-01      17.020
#             Harare        5607  2013-07-01      16.299
#             Harare        5608  2013-08-01      19.232
#             Harare        5609  2013-09-01         NaN
#
# [16500 rows x 3 columns]

# %%
# passing the level of sort as city

print(temperatures_ind.sort_index(level=['city'],ascending=[True]))
# Out:
#                        Unnamed: 0        date  avg_temp_c
# country       city
# Côte D'Ivoire Abidjan           0  2000-01-01      27.293
#               Abidjan           1  2000-02-01      27.685
#               Abidjan           2  2000-03-01      29.061
#               Abidjan           3  2000-04-01      28.162
#               Abidjan           4  2000-05-01      27.547
# ...                           ...         ...         ...
# China         Xian          16495  2013-05-01      18.979
#               Xian          16496  2013-06-01      23.522
#               Xian          16497  2013-07-01      25.251
#               Xian          16498  2013-08-01      24.528
#               Xian          16499  2013-09-01         NaN
#
# [16500 rows x 3 columns]

# %%
# sorting index by ascending country and descending city

print(temperatures_ind.sort_index(level=['country','city'],ascending=[True,False]))
# Out:
#                     Unnamed: 0        date  avg_temp_c
# country     city
# Afghanistan Kabul         7260  2000-01-01       3.326
#             Kabul         7261  2000-02-01       3.454
#             Kabul         7262  2000-03-01       9.612
#             Kabul         7263  2000-04-01      17.925
#             Kabul         7264  2000-05-01      24.658
# ...                        ...         ...         ...
# Zimbabwe    Harare        5605  2013-05-01      18.298
#             Harare        5606  2013-06-01      17.020
#             Harare        5607  2013-07-01      16.299
#             Harare        5608  2013-08-01      19.232
#             Harare        5609  2013-09-01         NaN
#
# [16500 rows x 3 columns]

# %% [markdown]
# # Slicing and subsetting with loc and iloc

# %% [raw]
# Sort the index of temperatures_ind.
# Use slicing with .loc[] to get these subsets:
# from Pakistan to Russia.
# from Lahore to Moscow. (This will return nonsense.)
# from Pakistan, Lahore to Russia, Moscow.

# %%
#sorting the index of temperatures_ind

temperatures_srt=temperatures_ind.sort_index()

# %%
# from pakstan to russia as outer index 

print(temperatures_srt.loc['Pakistan':'Russia'])
# Out:
#                            Unnamed: 0        date  avg_temp_c
# country  city
# Pakistan Faisalabad              4785  2000-01-01      12.792
#          Faisalabad              4786  2000-02-01      14.339
#          Faisalabad              4787  2000-03-01      20.309
#          Faisalabad              4788  2000-04-01      29.072
#          Faisalabad              4789  2000-05-01      34.845
# ...                               ...         ...         ...
# Russia   Saint Petersburg       13360  2013-05-01      12.355
#          Saint Petersburg       13361  2013-06-01      17.185
#          Saint Petersburg       13362  2013-07-01      17.234
#          Saint Petersburg       13363  2013-08-01      17.153
#          Saint Petersburg       13364  2013-09-01         NaN
#
# [1155 rows x 3 columns]

# %%
# from Lahore to Moscow. (This will return nonsense.)

print(temperatures_srt.loc['Lahore':'Moscow'])
# Out:
#                     Unnamed: 0        date  avg_temp_c
# country city
# Mexico  Mexico           10230  2000-01-01      12.694
#         Mexico           10231  2000-02-01      14.677
#         Mexico           10232  2000-03-01      17.376
#         Mexico           10233  2000-04-01      18.294
#         Mexico           10234  2000-05-01      18.562
# ...                        ...         ...         ...
# Morocco Casablanca        3130  2013-05-01      19.217
#         Casablanca        3131  2013-06-01      23.649
#         Casablanca        3132  2013-07-01      27.488
#         Casablanca        3133  2013-08-01      27.952
#         Casablanca        3134  2013-09-01         NaN
#
# [330 rows x 3 columns]

# %%
# from Pakistan, Lahore to Russia, Moscow.

print(temperatures_srt.loc[('Pakistan,Lahore'):('Russia','Moscow')])
# Out:
#                 Unnamed: 0        date  avg_temp_c
# country city
# Peru    Lima          8745  2000-01-01      19.455
#         Lima          8746  2000-02-01      20.911
#         Lima          8747  2000-03-01      20.113
#         Lima          8748  2000-04-01      18.726
#         Lima          8749  2000-05-01      16.710
# ...                    ...         ...         ...
# Russia  Moscow       10885  2013-05-01      16.152
#         Moscow       10886  2013-06-01      18.718
#         Moscow       10887  2013-07-01      18.136
#         Moscow       10888  2013-08-01      17.485
#         Moscow       10889  2013-09-01         NaN
#
# [495 rows x 3 columns]

# %% [raw]
# Use .loc[] slicing to subset rows from India, Hyderabad to Iraq, Baghdad.
# Use .loc[] slicing to subset columns from date to avg_temp_c.
# Slice in both directions at once from Hyderabad to Baghdad, and date to avg_temp_c.

# %%
# Use .loc[] slicing to subset rows from India, Hyderabad to Iraq, Baghdad.
print(temperatures_srt.loc[('India','Hyderabad'):('Iraq','Baghdad')])
# Out:
#                    Unnamed: 0        date  avg_temp_c
# country city
# India   Hyderabad        5940  2000-01-01      23.779
#         Hyderabad        5941  2000-02-01      25.826
#         Hyderabad        5942  2000-03-01      28.821
#         Hyderabad        5943  2000-04-01      32.698
#         Hyderabad        5944  2000-05-01      32.438
# ...                       ...         ...         ...
# Iraq    Baghdad          1150  2013-05-01      28.673
#         Baghdad          1151  2013-06-01      33.803
#         Baghdad          1152  2013-07-01      36.392
#         Baghdad          1153  2013-08-01      35.463
#         Baghdad          1154  2013-09-01         NaN
#
# [2145 rows x 3 columns]

# %%
# Use .loc[] slicing to subset columns from date to avg_temp_c.

# %%
print(temperatures_srt.loc[:,'date':'avg_temp_c'])
# Out:
#                           date  avg_temp_c
# country     city
# Afghanistan Kabul   2000-01-01       3.326
#             Kabul   2000-02-01       3.454
#             Kabul   2000-03-01       9.612
#             Kabul   2000-04-01      17.925
#             Kabul   2000-05-01      24.658
# ...                        ...         ...
# Zimbabwe    Harare  2013-05-01      18.298
#             Harare  2013-06-01      17.020
#             Harare  2013-07-01      16.299
#             Harare  2013-08-01      19.232
#             Harare  2013-09-01         NaN
#
# [16500 rows x 2 columns]

# %%
# Slice in both directions at once from Hyderabad to Baghdad, and date to avg_temp_c.

print(temperatures_srt.loc[('India','Hyderabad'):('Iraq','Baghdad'),'date':'avg_temp_c'])
# Out:
#                          date  avg_temp_c
# country city
# India   Hyderabad  2000-01-01      23.779
#         Hyderabad  2000-02-01      25.826
#         Hyderabad  2000-03-01      28.821
#         Hyderabad  2000-04-01      32.698
#         Hyderabad  2000-05-01      32.438
# ...                       ...         ...
# Iraq    Baghdad    2013-05-01      28.673
#         Baghdad    2013-06-01      33.803
#         Baghdad    2013-07-01      36.392
#         Baghdad    2013-08-01      35.463
#         Baghdad    2013-09-01         NaN
#
# [2145 rows x 2 columns]

# %% [raw]
# Use Boolean conditions, not .isin() or .loc[], and the full date "yyyy-mm-dd", to subset temperatures for rows in 2010 and 2011 and print the results.
# Set the index of temperatures to the date column and sort it.
# Use .loc[] to subset temperatures_ind for rows in 2010 and 2011.
# Use .loc[] to subset temperatures_ind for rows from Aug 2010 to Feb 2011.

# %%
# Use Boolean conditions, not .isin() or .loc[], and the full date "yyyy-mm-dd", to subset temperatures for rows in 2010 and 2011 and print the results.
# Use Boolean conditions to subset temperatures for rows in 2010 and 2011
temperature_bool=temperatures[(temperatures['date']>='2010-01-01')&(temperatures[temperatures['date']<='2011-12-31'])]
temperature_bool

# %%
# Set the index of temperatures to the date column and sort it.

temperatures_ind=temperatures.set_index('date').sort_index()
temperatures_ind
# Out:
#             Unnamed: 0       city        country  avg_temp_c
# date
# 2000-01-01           0    Abidjan  Côte D'Ivoire      27.293
# 2000-01-01        8415     Lahore       Pakistan      12.792
# 2000-01-01       15345   Tangshan          China      -5.406
# 2000-01-01        5115      Gizeh          Egypt      12.669
# 2000-01-01        8580    Lakhnau          India      15.152
# ...                ...        ...            ...         ...
# 2013-09-01       11549    Nanjing          China         NaN
# 2013-09-01       11714  New Delhi          India         NaN
# 2013-09-01       11879   New York  United States      17.408
# 2013-09-01       12209     Peking          China         NaN
# 2013-09-01       16499       Xian          China         NaN
#
# [16500 rows x 4 columns]

# %%
# Use .loc[] to subset temperatures_ind for rows in 2010 and 2011.

print(temperatures_ind.loc['2010':'2011'])
# Out:
#             Unnamed: 0        city    country  avg_temp_c
# date
# 2010-01-01        4905  Faisalabad   Pakistan      11.810
# 2010-01-01       10185   Melbourne  Australia      20.016
# 2010-01-01        3750   Chongqing      China       7.921
# 2010-01-01       13155   São Paulo     Brazil      23.738
# 2010-01-01        5400   Guangzhou      China      14.136
# ...                ...         ...        ...         ...
# 2010-12-01        6896     Jakarta  Indonesia      26.602
# 2010-12-01        5246       Gizeh      Egypt      16.530
# 2010-12-01       11186      Nagpur      India      19.120
# 2010-12-01       14981      Sydney  Australia      19.559
# 2010-12-01       13496    Salvador     Brazil      26.265
#
# [1200 rows x 4 columns]

# %%
# Use .loc[] to subset temperatures_ind for rows from Aug 2010 to Feb 2011.

print(temperatures_ind.loc['2010-08-01':'2011-02-28'])
# Out:
#             Unnamed: 0      city        country  avg_temp_c
# date
# 2010-08-01        2602  Calcutta          India      30.226
# 2010-08-01       12337      Pune          India      24.941
# 2010-08-01        6562     Izmir         Turkey      28.352
# 2010-08-01       15637   Tianjin          China      25.543
# 2010-08-01        9862    Manila    Philippines      27.101
# ...                ...       ...            ...         ...
# 2011-02-01        7393     Kabul    Afghanistan       3.914
# 2011-02-01        3598   Chicago  United States       0.276
# 2011-02-01         628    Aleppo          Syria       8.246
# 2011-02-01        4423     Delhi          India      18.136
# 2011-02-01       12508   Rangoon          Burma      26.631
#
# [700 rows x 4 columns]

# %% [markdown]
# # Use .iloc[] on temperatures to take subsets.

# %% [raw]
# Get the 23rd row, 2nd column (index positions 22 and 1).
# Get the first 5 rows (index positions 0 to 5).
# Get all rows, columns 3 and 4 (index positions 2 to 4).
# Get the first 5 rows, columns 3 and 4.

# %%
# Get the 23rd row, 2nd column (index positions 22 and 1).

temperatures.iloc[22:23,1:2]
# Out:
#           date
# 22  2001-11-01

# %%
# Get the first 5 rows (index positions 0 to 5).
temperatures.iloc[0:5,:]
# Out:
#    Unnamed: 0        date     city        country  avg_temp_c
# 0           0  2000-01-01  Abidjan  Côte D'Ivoire      27.293
# 1           1  2000-02-01  Abidjan  Côte D'Ivoire      27.685
# 2           2  2000-03-01  Abidjan  Côte D'Ivoire      29.061
# 3           3  2000-04-01  Abidjan  Côte D'Ivoire      28.162
# 4           4  2000-05-01  Abidjan  Côte D'Ivoire      27.547

# %%
# Get all rows, columns 3 and 4 (index positions 2 to 4).

# %%
temperatures.iloc[:,2:4]
# Out:
#           city        country
# 0      Abidjan  Côte D'Ivoire
# 1      Abidjan  Côte D'Ivoire
# 2      Abidjan  Côte D'Ivoire
# 3      Abidjan  Côte D'Ivoire
# 4      Abidjan  Côte D'Ivoire
# ...        ...            ...
# 16495     Xian          China
# 16496     Xian          China
# 16497     Xian          China
# 16498     Xian          China
# 16499     Xian          China
#
# [16500 rows x 2 columns]

# %%
# Get the first 5 rows, columns 3 and 4.

temperatures.iloc[0:5,2:4]
# Out:
#       city        country
# 0  Abidjan  Côte D'Ivoire
# 1  Abidjan  Côte D'Ivoire
# 2  Abidjan  Côte D'Ivoire
# 3  Abidjan  Côte D'Ivoire
# 4  Abidjan  Côte D'Ivoire

# %% [markdown]
# # Working with pivot tables

# %% [raw]
# Add a year column to temperatures, from the year component of the date column.
# Make a pivot table of the avg_temp_c column, with country and city as rows, and year as columns. Assign to temp_by_country_city_vs_year, and look at the result.

# %%
temperatures.head()
# Out:
#    Unnamed: 0        date     city        country  avg_temp_c
# 0           0  2000-01-01  Abidjan  Côte D'Ivoire      27.293
# 1           1  2000-02-01  Abidjan  Côte D'Ivoire      27.685
# 2           2  2000-03-01  Abidjan  Côte D'Ivoire      29.061
# 3           3  2000-04-01  Abidjan  Côte D'Ivoire      28.162
# 4           4  2000-05-01  Abidjan  Côte D'Ivoire      27.547

# %%
# Add a year column to temperatures, from the year component of the date column.
 temperatures['year']=temperatures['date'].dt.year

# %%
# Make a pivot table of the avg_temp_c column, with country and city as rows, 
# and year as columns. Assign to temp_by_country_city_vs_year, and look at the result.

temp_by_country_city_vs_year= temperatures.pivot_table(values='avg_temp_c',index=['city','country'],columns='year')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 4
#       1 # Make a pivot table of the avg_temp_c column, with country and city as rows,
#       2 # and year as columns. Assign to temp_by_country_city_vs_year, and look at the result.
# ----> 4 temp_by_country_city_vs_year= temperatures.pivot_table(values='avg_temp_c',index=['city','country'],columns='year')
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:8731, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    8714 @Substitution("")
#    8715 @Appender(_shared_docs["pivot_table"])
#    8716 def pivot_table(
#    (...)
#    8727     sort=True,
#    8728 ) -> DataFrame:
#    8729     from pandas.core.reshape.pivot import pivot_table
# -> 8731     return pivot_table(
#    8732         self,
#    8733         values=values,
# ...

# %%
Use .loc[] on temp_by_country_city_vs_year to take subsets.

From Egypt to India.
From Egypt, Cairo to India, Delhi.
From Egypt, Cairo to India, Delhi, and 2005 to 2010.

# %%
temp_by_country_city_vs_year.loc['Egypt':'India']

# %%
temp_by_country_city_vs_year.loc[('Egypt,Cairo'):('India,Delhi')]

# %%
temp_bt_country_city_vs_year.loc[('Egypt,Cairo'):('India,Delhi'),'2005':'2010']

# %% [markdown]
# # Visualizing your data

# %%
import matplotlib.pyplot as plt

# %%
avocados=pd.read_pickle('avoplotto.pkl')
avocados.head()
# Out:
#          date          type  year  avg_price   size     nb_sold
# 0  2015-12-27  conventional  2015       0.95  small  9626901.09
# 1  2015-12-20  conventional  2015       0.98  small  8710021.76
# 2  2015-12-13  conventional  2015       0.93  small  9855053.66
# 3  2015-12-06  conventional  2015       0.89  small  9405464.36
# 4  2015-11-29  conventional  2015       0.99  small  8094803.56

# %% [raw]
# Print the head of the avocados dataset. What columns are available?
# For each avocado size group, calculate the total number sold, storing as nb_sold_by_size.
# Create a bar plot of the number of avocados sold by size.
# Show the plot.

# %%
# Print the head of the avocados dataset. What columns are available?
 
avocados.head()
# Out:
#          date          type  year  avg_price   size     nb_sold
# 0  2015-12-27  conventional  2015       0.95  small  9626901.09
# 1  2015-12-20  conventional  2015       0.98  small  8710021.76
# 2  2015-12-13  conventional  2015       0.93  small  9855053.66
# 3  2015-12-06  conventional  2015       0.89  small  9405464.36
# 4  2015-11-29  conventional  2015       0.99  small  8094803.56

# %%
# For each avocado size group, calculate the total number sold, storing as nb_sold_by_size.
nb_sold_by_size=avocados.groupby('size')['nb_sold'].sum()
nb_sold_by_size
# Out:
# size
# extra_large    1.561752e+08
# large          2.015012e+09
# small          2.054936e+09
# Name: nb_sold, dtype: float64

# %% [markdown]
# # Barchat

# %%
# Create a bar plot of the number of avocados sold by size
nb_sold_by_size.plot(kind='bar')
# Show the plot
plt.show()

# %% [raw]
# Get the total number of avocados sold on each date. The DataFrame has two rows for each date—one for organic, and one for conventional. Save this as nb_sold_by_date.
# Create a line plot of the number of avocados sold.
# Show the plot.

# %% [markdown]
# # Line plot

# %%
# Get the total number of avocados sold on each date. 
# The DataFrame has two rows for each date—one for organic, and one for conventional. Save this as nb_sold_by_date.

nb_sold_by_date= avocados.groupby('date')['nb_sold'].sum()

# %%
# Create a line plot of the number of avocados sold.

nb_sold_by_date.plot(kind='line')
# Show the plot.
plt.show()

# %% [raw]
# Create a scatter plot with nb_sold on the x-axis and avg_price on the y-axis. Title it "Number of avocados sold vs. average price".
# Show the plot.

# %% [markdown]
# # scatter plot

# %%
# Create a scatter plot with nb_sold on the x-axis and avg_price on the y-axis. 
# Title it "Number of avocados sold vs. average price".

avocados.plot(kind='scatter',y='avg_price',x='nb_sold',title='Number of avocados sold vs.average price')
# show the plot 
plt.show()

# %% [raw]
# Subset avocados for the conventional type, and the average price column. Create a histogram.
# Create a histogram of avg_price for organic type avocados.
# Add a legend to your plot, with the names "conventional" and "organic".
# Show your plot.

# %% [markdown]
# # Histogram

# %%
# Subset avocados for the conventional type, and the average price column. Create a histogram.
# we use the alpha paramete to adjust the transparent 
# we use the bins to make the represantaion well 

avocados[avocados['type']=='conventional']['avg_price'].hist(alpha=0.5,bins=20)
# Create a histogram of avg_price for organic type avocados.
avocados[avocados['type']=='organic']['avg_price'].hist(alpha=0.5,bins=20)
# Add a legend to your plot, with the names "conventional" and "organic".
plt.legend(['Convetional','Organic'])

# %% [markdown]
# # Missing Values

# %% [markdown]
# # isna().any()

# %%
avocados.head()
# Out:
#          date          type  year  avg_price   size     nb_sold
# 0  2015-12-27  conventional  2015       0.95  small  9626901.09
# 1  2015-12-20  conventional  2015       0.98  small  8710021.76
# 2  2015-12-13  conventional  2015       0.93  small  9855053.66
# 3  2015-12-06  conventional  2015       0.89  small  9405464.36
# 4  2015-11-29  conventional  2015       0.99  small  8094803.56

# %%
avocados_2016=avocados[avocados["year"]>=2016]
avocados_2016
# Out:
#             date          type  year  avg_price         size      nb_sold
# 52    2016-12-25  conventional  2016       1.00        small   9255125.20
# 53    2016-12-18  conventional  2016       0.96        small   9394065.91
# 54    2016-12-11  conventional  2016       0.98        small   9009996.11
# 55    2016-12-04  conventional  2016       1.00        small  11043350.90
# 56    2016-11-27  conventional  2016       1.21        small   7891487.94
# ...          ...           ...   ...        ...          ...          ...
# 1009  2018-02-04       organic  2018       1.53  extra_large      1703.52
# 1010  2018-01-28       organic  2018       1.61  extra_large      1270.61
# 1011  2018-01-21       organic  2018       1.63  extra_large      1490.02
# 1012  2018-01-14       organic  2018       1.59  extra_large      1580.01
# 1013  2018-01-07       organic  2018       1.51  extra_large      1289.07
#
# [702 rows x 6 columns]

# %%
avocados_2016.isna().sum()
# Out:
# date         0
# type         0
# year         0
# avg_price    0
# size         0
# nb_sold      0
# dtype: int64

# %% [raw]
# Print a DataFrame that shows whether each value in avocados_2016 is missing or not.
# Print a summary that shows whether any value in each column is missing or not.
# Create a bar plot of the total number of missing values in each column.

# %%
# Print a DataFrame that shows whether each value in avocados_2016 is missing or not.

avocados_2016.isna()
# Out:
#        date   type   year  avg_price   size  nb_sold
# 52    False  False  False      False  False    False
# 53    False  False  False      False  False    False
# 54    False  False  False      False  False    False
# 55    False  False  False      False  False    False
# 56    False  False  False      False  False    False
# ...     ...    ...    ...        ...    ...      ...
# 1009  False  False  False      False  False    False
# 1010  False  False  False      False  False    False
# 1011  False  False  False      False  False    False
# 1012  False  False  False      False  False    False
# 1013  False  False  False      False  False    False
#
# [702 rows x 6 columns]

# %%
# Print a summary that shows whether any value in each column is missing or not.
avocados.isna().any()
# Out:
# date         False
# type         False
# year         False
# avg_price    False
# size         False
# nb_sold      False
# dtype: bool

# %%
# Create a bar plot of the total number of missing values in each column.
avocados.isna().sum().plot(kind='bar')
# Out:
# <Axes: >

# %% [raw]
# Remove the rows of avocados_2016 that contain missing values and store the remaining rows in avocados_complete.
# Verify that all missing values have been removed from avocados_complete. Calculate each column that has NAs and print.

# %%
avocados_complete=avocaso

# %%
# subset using isin()
# here to find the dogs which are black or blown in dataset

is_black_or_brown = dogs['color'].isin(['Black','Brown'])

# %% [markdown]
# # Adding new colmun

# %%
# let say you want to add the colun that contain the heigh of dag in meter instesd of meter 



dogs['Height_m']= dogs['Heigh_cm']/100

# let say we want to calculate the BMI= weight in kg/ (height in m)**2

dogs['BMI']= dogs['weight']/(dogs['Height_m'])**2 # the column will be added here
