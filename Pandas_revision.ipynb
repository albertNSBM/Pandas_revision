# %%
# importing the necessary library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# loading the data
df=pd.read_csv("/content/drive/MyDrive/AI6 Kigali DL/Torch_revision/homelessness.csv")

# %%
# heading of the data
df.head()
# Out:
#    Unnamed: 0              region       state  individuals  family_members  \
# 0           0  East South Central     Alabama       2570.0           864.0
# 1           1             Pacific      Alaska       1434.0           582.0
# 2           2            Mountain     Arizona       7259.0          2606.0
# 3           3  West South Central    Arkansas       2280.0           432.0
# 4           4             Pacific  California     109008.0         20964.0
#
#    state_pop
# 0    4887681
# 1     735139
# 2    7158024
# 3    3009733
# 4   39461588

# %%
# Distplaying the columns names

df.columns
# Out:
# Index(['Unnamed: 0', 'region', 'state', 'individuals', 'family_members',
#        'state_pop'],
#       dtype='object')

# %%
# distplaying the values of the dataframe as numpay

df.values
# Out:
# array([[0, 'East South Central', 'Alabama', 2570.0, 864.0, 4887681],
#        [1, 'Pacific', 'Alaska', 1434.0, 582.0, 735139],
#        [2, 'Mountain', 'Arizona', 7259.0, 2606.0, 7158024],
#        [3, 'West South Central', 'Arkansas', 2280.0, 432.0, 3009733],
#        [4, 'Pacific', 'California', 109008.0, 20964.0, 39461588],
#        [5, 'Mountain', 'Colorado', 7607.0, 3250.0, 5691287],
#        [6, 'New England', 'Connecticut', 2280.0, 1696.0, 3571520],
#        [7, 'South Atlantic', 'Delaware', 708.0, 374.0, 965479],
#        [8, 'South Atlantic', 'District of Columbia', 3770.0, 3134.0,
#         701547],
#        [9, 'South Atlantic', 'Florida', 21443.0, 9587.0, 21244317],
#        [10, 'South Atlantic', 'Georgia', 6943.0, 2556.0, 10511131],
#        [11, 'Pacific', 'Hawaii', 4131.0, 2399.0, 1420593],
#        [12, 'Mountain', 'Idaho', 1297.0, 715.0, 1750536],
#        [13, 'East North Central', 'Illinois', 6752.0, 3891.0, 12723071],
# ...

# %%
# Displaying the index we have in our dataset or number of row

df.index
# Out:
# RangeIndex(start=0, stop=51, step=1)

# %% [markdown]
# # Sorting and Subsetting

# %%
# .sort_values(column_name, argument or order)

df.sort_values("state", ascending=[True]) # one column
df.sort_values(['state','region'], ascending=[False,True])# for multiple columns
# Out:
#     Unnamed: 0              region                 state  individuals  \
# 0            0  East South Central               Alabama       2570.0
# 1            1             Pacific                Alaska       1434.0
# 2            2            Mountain               Arizona       7259.0
# 3            3  West South Central              Arkansas       2280.0
# 4            4             Pacific            California     109008.0
# 5            5            Mountain              Colorado       7607.0
# 6            6         New England           Connecticut       2280.0
# 7            7      South Atlantic              Delaware        708.0
# 8            8      South Atlantic  District of Columbia       3770.0
# 9            9      South Atlantic               Florida      21443.0
# 10          10      South Atlantic               Georgia       6943.0
# 11          11             Pacific                Hawaii       4131.0
# ...

# %% [markdown]
# # Subsetting rows

# %%
# checking the values of one column only

df['state'] # for one column
df[["state","region"]] # selecting multiple columns
# Out:
#                    state              region
# 0                Alabama  East South Central
# 1                 Alaska             Pacific
# 2                Arizona            Mountain
# 3               Arkansas  West South Central
# 4             California             Pacific
# 5               Colorado            Mountain
# 6            Connecticut         New England
# 7               Delaware      South Atlantic
# 8   District of Columbia      South Atlantic
# 9                Florida      South Atlantic
# 10               Georgia      South Atlantic
# 11                Hawaii             Pacific
# 12                 Idaho            Mountain
# 13              Illinois  East North Central
# 14               Indiana  East North Central
# 15                  Iowa  West North Central
# 16                Kansas  West North Central
# 17              Kentucky  East South Central
# 18             Louisiana  West South Central
# 19                 Maine         New England
# ...

# %%
# using boolean
# find the all state whose region is not the West North Central

df[df['region']=='West North Central']
# Out:
#     Unnamed: 0              region         state  individuals  family_members  \
# 15          15  West North Central          Iowa       1711.0          1038.0
# 16          16  West North Central        Kansas       1443.0           773.0
# 23          23  West North Central     Minnesota       3993.0          3250.0
# 25          25  West North Central      Missouri       3776.0          2107.0
# 27          27  West North Central      Nebraska       1745.0           676.0
# 34          34  West North Central  North Dakota        467.0            75.0
# 41          41  West North Central  South Dakota        836.0           323.0
#
#     state_pop
# 15    3148618
# 16    2911359
# 23    5606249
# 25    6121623
# 27    1925614
# 34     758080
# 41     878698

# %%
# subset using isin()
# here to find the dogs which are black or blown in dataset

is_black_or_brown = dogs['color'].isin(['Black','Brown'])

# %% [markdown]
# # Adding new colmun
